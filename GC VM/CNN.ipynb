# %%
# !pip install pydot
# !pip install graphviz
# Out:
# Requirement already satisfied: pydot in c:\users\katre\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: pyparsing>=2.1.4 in c:\users\katre\anaconda3\lib\site-packages (from pydot) (3.0.9)
# Requirement already satisfied: graphviz in c:\users\katre\anaconda3\lib\site-packages (0.20.1)

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %%
train_path = 'seg_train/seg_train/'
test_path = 'seg_test/seg_test/'

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

# %%
val_test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_data = train_datagen.flow_from_directory(
    train_path,
    target_size=(150, 150),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 14034 images belonging to 6 classes.

# %%
val_data = val_test_datagen.flow_from_directory(
    test_path,
    target_size=(150, 150),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 3000 images belonging to 6 classes.

# %%
test_data = val_test_datagen.flow_from_directory(
    test_path,
    target_size=(150, 150),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 3000 images belonging to 6 classes.

# %%
# Build the CNN model
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(6, activation='softmax')
])

# %%
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model
history = model.fit(train_data, epochs=10, validation_data=val_data)
# Out:
# Epoch 1/10
# 439/439 [==============================] - 205s 465ms/step - loss: 1.0434 - accuracy: 0.6087 - val_loss: 0.7554 - val_accuracy: 0.7233
# Epoch 2/10
# 439/439 [==============================] - 190s 433ms/step - loss: 0.7352 - accuracy: 0.7287 - val_loss: 0.6678 - val_accuracy: 0.7633
# Epoch 3/10
# 439/439 [==============================] - 190s 432ms/step - loss: 0.6376 - accuracy: 0.7670 - val_loss: 0.6156 - val_accuracy: 0.7923
# Epoch 4/10
# 439/439 [==============================] - 191s 434ms/step - loss: 0.5622 - accuracy: 0.7999 - val_loss: 0.6427 - val_accuracy: 0.7883
# Epoch 5/10
# 439/439 [==============================] - 194s 441ms/step - loss: 0.5089 - accuracy: 0.8134 - val_loss: 0.6225 - val_accuracy: 0.7890
# Epoch 6/10
# 439/439 [==============================] - 187s 427ms/step - loss: 0.4720 - accuracy: 0.8331 - val_loss: 0.4855 - val_accuracy: 0.8430
# Epoch 7/10
# 439/439 [==============================] - 177s 402ms/step - loss: 0.4460 - accuracy: 0.8397 - val_loss: 0.5253 - val_accuracy: 0.8277
# Epoch 8/10
# 439/439 [==============================] - 189s 431ms/step - loss: 0.4169 - accuracy: 0.8502 - val_loss: 0.5578 - val_accuracy: 0.8197
# Epoch 9/10
# 439/439 [==============================] - 184s 419ms/step - loss: 0.3919 - accuracy: 0.8620 - val_loss: 0.4781 - val_accuracy: 0.8410
# Epoch 10/10
# 439/439 [==============================] - 177s 403ms/step - loss: 0.3710 - accuracy: 0.8670 - val_loss: 0.5020 - val_accuracy: 0.8360

# %%
# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(test_data)
print(f'Test Accuracy: {test_acc}')

# Confusion Matrix
predictions = model.predict(test_data)
conf_matrix = confusion_matrix(test_data.classes, np.argmax(predictions, axis=1))

# Display confusion matrix
print('Confusion Matrix:')
print(conf_matrix)

# Classification Report
class_report = classification_report(test_data.classes, np.argmax(predictions, axis=1))
print('Classification Report:')
print(class_report)
# Out:
# 94/94 [==============================] - 6s 68ms/step - loss: 0.5020 - accuracy: 0.8360
# Test Accuracy: 0.8360000252723694
# 94/94 [==============================] - 7s 67ms/step
# Confusion Matrix:
# [[323   9   5  19  20  61]
#  [  1 458   4   9   1   1]
#  [  4   4 422  88  32   3]
#  [  1   2  50 429  43   0]
#  [  8   3  27  20 445   7]
#  [ 35  18   6   7   4 431]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.74      0.80       437
#            1       0.93      0.97      0.95       474
#            2       0.82      0.76      0.79       553
#            3       0.75      0.82      0.78       525
#            4       0.82      0.87      0.84       510
#            5       0.86      0.86      0.86       501
#
#     accuracy                           0.84      3000
#    macro avg       0.84      0.84      0.84      3000
# weighted avg       0.84      0.84      0.84      3000

# %%
# Display model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 74, 74, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 36, 36, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 82944)             0
#
#  dense (Dense)               (None, 128)               10616960
#
#  dense_1 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 10637126 (40.58 MB)
# Trainable params: 10637126 (40.58 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# Specify the number of folds
n_folds = 10

# Get the data and labels
X = train_data[0][0]
y = train_data[0][1]

# Convert labels to integer indices
y_indices = np.argmax(y, axis=1)

# Initialize StratifiedShuffleSplit
sss = StratifiedShuffleSplit(n_splits=n_folds, test_size=len(np.unique(y_indices)), random_state=42)


# Iterate through folds
for fold, (train_index, val_index) in enumerate(sss.split(X, y_indices), 1):
    print(f"\nFold {fold}/{n_folds}")

    # Create the CNN model
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(6, activation='softmax')
    ])
    # Compile the model
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    # Split the data into train and validation sets
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]

    # Create data generators for train and validation sets
    train_data_fold = train_datagen.flow(X_train, y_train, batch_size=32)
    val_data_fold = train_datagen.flow(X_val, y_val, batch_size=32)

    # Train the model
    history = model.fit(train_data_fold, epochs=10, validation_data=val_data_fold)

    # Evaluate the model on the test set
    test_loss, test_acc = model.evaluate(test_data)
    print(f'Test Accuracy for Fold {fold}: {test_acc}')

    # Display model summary
    model.summary()
# Out:
# Fold 1/10
# Epoch 1/10
# 1/1 [==============================] - 2s 2s/step - loss: 1.7918 - accuracy: 0.1538 - val_loss: 1.7787 - val_accuracy: 0.3333
# Epoch 2/10
# 1/1 [==============================] - 1s 641ms/step - loss: 1.7831 - accuracy: 0.2692 - val_loss: 1.7185 - val_accuracy: 0.3333
# Epoch 3/10
# 1/1 [==============================] - 1s 599ms/step - loss: 1.7530 - accuracy: 0.2692 - val_loss: 1.6832 - val_accuracy: 0.3333
# Epoch 4/10
# 1/1 [==============================] - 1s 579ms/step - loss: 1.7670 - accuracy: 0.2692 - val_loss: 1.6915 - val_accuracy: 0.3333
# Epoch 5/10
# 1/1 [==============================] - 1s 561ms/step - loss: 1.7457 - accuracy: 0.2692 - val_loss: 1.7120 - val_accuracy: 0.3333
# Epoch 6/10
# 1/1 [==============================] - 1s 558ms/step - loss: 1.7447 - accuracy: 0.2692 - val_loss: 1.7195 - val_accuracy: 0.3333
# Epoch 7/10
# 1/1 [==============================] - 1s 550ms/step - loss: 1.7452 - accuracy: 0.2692 - val_loss: 1.7148 - val_accuracy: 0.3333
# Epoch 8/10
# 1/1 [==============================] - 1s 556ms/step - loss: 1.7412 - accuracy: 0.2692 - val_loss: 1.6970 - val_accuracy: 0.3333
# Epoch 9/10
# 1/1 [==============================] - 1s 589ms/step - loss: 1.7328 - accuracy: 0.2692 - val_loss: 1.6765 - val_accuracy: 0.3333
# Epoch 10/10
# 1/1 [==============================] - 1s 614ms/step - loss: 1.7227 - accuracy: 0.2692 - val_loss: 1.6622 - val_accuracy: 0.3333
# 94/94 [==============================] - 10s 104ms/step - loss: 25.8503 - accuracy: 0.1460
# Test Accuracy for Fold 1: 0.1459999978542328
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 148, 148, 32)      896
#
#  max_pooling2d_2 (MaxPoolin  (None, 74, 74, 32)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_3 (MaxPoolin  (None, 36, 36, 64)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 82944)             0
#
#  dense_2 (Dense)             (None, 128)               10616960
#
#  dense_3 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 10637126 (40.58 MB)
# Trainable params: 10637126 (40.58 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
# Fold 2/10
# Epoch 1/10
# 1/1 [==============================] - 1s 1s/step - loss: 1.7917 - accuracy: 0.1538 - val_loss: 1.7744 - val_accuracy: 0.3333
# Epoch 2/10
# 1/1 [==============================] - 0s 466ms/step - loss: 1.7784 - accuracy: 0.2692 - val_loss: 1.7179 - val_accuracy: 0.3333
# Epoch 3/10
# 1/1 [==============================] - 0s 485ms/step - loss: 1.7485 - accuracy: 0.2692 - val_loss: 1.7058 - val_accuracy: 0.3333
# Epoch 4/10
# 1/1 [==============================] - 0s 461ms/step - loss: 1.7929 - accuracy: 0.2692 - val_loss: 1.6853 - val_accuracy: 0.3333
# Epoch 5/10
# 1/1 [==============================] - 0s 478ms/step - loss: 1.7455 - accuracy: 0.2692 - val_loss: 1.7123 - val_accuracy: 0.3333
# Epoch 6/10
# 1/1 [==============================] - 0s 476ms/step - loss: 1.7459 - accuracy: 0.2692 - val_loss: 1.7343 - val_accuracy: 0.3333
# Epoch 7/10
# 1/1 [==============================] - 0s 472ms/step - loss: 1.7536 - accuracy: 0.2692 - val_loss: 1.7404 - val_accuracy: 0.3333
# Epoch 8/10
# 1/1 [==============================] - 0s 472ms/step - loss: 1.7541 - accuracy: 0.2692 - val_loss: 1.7373 - val_accuracy: 0.3333
# Epoch 9/10
# 1/1 [==============================] - 0s 471ms/step - loss: 1.7473 - accuracy: 0.2692 - val_loss: 1.7271 - val_accuracy: 0.3333
# Epoch 10/10
# 1/1 [==============================] - 0s 450ms/step - loss: 1.7366 - accuracy: 0.2692 - val_loss: 1.7114 - val_accuracy: 0.3333
# 94/94 [==============================] - 6s 65ms/step - loss: 18.1026 - accuracy: 0.1613
# Test Accuracy for Fold 2: 0.1613333374261856
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 148, 148, 32)      896
#
#  max_pooling2d_4 (MaxPoolin  (None, 74, 74, 32)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_5 (MaxPoolin  (None, 36, 36, 64)        0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 82944)             0
#
#  dense_4 (Dense)             (None, 128)               10616960
#
#  dense_5 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 10637126 (40.58 MB)
# Trainable params: 10637126 (40.58 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
# Fold 3/10
# Epoch 1/10
# 1/1 [==============================] - 1s 1s/step - loss: 1.7917 - accuracy: 0.1923 - val_loss: 1.7808 - val_accuracy: 0.1667
# Epoch 2/10
# 1/1 [==============================] - 0s 468ms/step - loss: 1.7826 - accuracy: 0.1923 - val_loss: 1.7225 - val_accuracy: 0.3333
# Epoch 3/10
# 1/1 [==============================] - 0s 467ms/step - loss: 1.7478 - accuracy: 0.2692 - val_loss: 1.7092 - val_accuracy: 0.3333
# Epoch 4/10
# 1/1 [==============================] - 0s 478ms/step - loss: 1.7887 - accuracy: 0.2692 - val_loss: 1.6862 - val_accuracy: 0.3333
# Epoch 5/10
# 1/1 [==============================] - 0s 460ms/step - loss: 1.7429 - accuracy: 0.2692 - val_loss: 1.7052 - val_accuracy: 0.3333
# Epoch 6/10
# 1/1 [==============================] - 1s 509ms/step - loss: 1.7433 - accuracy: 0.2692 - val_loss: 1.7206 - val_accuracy: 0.3333
# Epoch 7/10
# 1/1 [==============================] - 0s 478ms/step - loss: 1.7467 - accuracy: 0.2692 - val_loss: 1.7233 - val_accuracy: 0.3333
# Epoch 8/10
# 1/1 [==============================] - 0s 477ms/step - loss: 1.7451 - accuracy: 0.2692 - val_loss: 1.7137 - val_accuracy: 0.3333
# Epoch 9/10
# 1/1 [==============================] - 0s 465ms/step - loss: 1.7356 - accuracy: 0.2692 - val_loss: 1.6943 - val_accuracy: 0.3333
# Epoch 10/10
# 1/1 [==============================] - 0s 471ms/step - loss: 1.7185 - accuracy: 0.2692 - val_loss: 1.6724 - val_accuracy: 0.3333
# 94/94 [==============================] - 6s 66ms/step - loss: 34.1509 - accuracy: 0.1457
# Test Accuracy for Fold 3: 0.1456666737794876
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 148, 148, 32)      896
#
#  max_pooling2d_6 (MaxPoolin  (None, 74, 74, 32)        0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_7 (MaxPoolin  (None, 36, 36, 64)        0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 82944)             0
#
#  dense_6 (Dense)             (None, 128)               10616960
#
#  dense_7 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 10637126 (40.58 MB)
# Trainable params: 10637126 (40.58 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
# Fold 4/10
# Epoch 1/10
# 1/1 [==============================] - 1s 1s/step - loss: 1.7918 - accuracy: 0.1538 - val_loss: 1.7864 - val_accuracy: 0.1667
# Epoch 2/10
# 1/1 [==============================] - 0s 482ms/step - loss: 1.7872 - accuracy: 0.1923 - val_loss: 1.7451 - val_accuracy: 0.3333
# Epoch 3/10
# 1/1 [==============================] - 0s 451ms/step - loss: 1.7627 - accuracy: 0.2692 - val_loss: 1.6987 - val_accuracy: 0.3333
# Epoch 4/10
# 1/1 [==============================] - 0s 443ms/step - loss: 1.7511 - accuracy: 0.2692 - val_loss: 1.6873 - val_accuracy: 0.3333
# Epoch 5/10
# 1/1 [==============================] - 0s 462ms/step - loss: 1.7461 - accuracy: 0.2692 - val_loss: 1.6913 - val_accuracy: 0.3333
# Epoch 6/10
# 1/1 [==============================] - 0s 460ms/step - loss: 1.7359 - accuracy: 0.2692 - val_loss: 1.6977 - val_accuracy: 0.3333
# Epoch 7/10
# 1/1 [==============================] - 0s 473ms/step - loss: 1.7330 - accuracy: 0.2692 - val_loss: 1.6899 - val_accuracy: 0.3333
# Epoch 8/10
# 1/1 [==============================] - 0s 449ms/step - loss: 1.7254 - accuracy: 0.2692 - val_loss: 1.6718 - val_accuracy: 0.3333
# Epoch 9/10
# 1/1 [==============================] - 0s 464ms/step - loss: 1.7142 - accuracy: 0.2692 - val_loss: 1.6518 - val_accuracy: 0.3333
# Epoch 10/10
# 1/1 [==============================] - 0s 452ms/step - loss: 1.7067 - accuracy: 0.2692 - val_loss: 1.6334 - val_accuracy: 0.3333
# 94/94 [==============================] - 6s 64ms/step - loss: 20.9768 - accuracy: 0.1467
# Test Accuracy for Fold 4: 0.14666666090488434
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 148, 148, 32)      896
#
#  max_pooling2d_8 (MaxPoolin  (None, 74, 74, 32)        0
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_9 (MaxPoolin  (None, 36, 36, 64)        0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 82944)             0
#
#  dense_8 (Dense)             (None, 128)               10616960
#
#  dense_9 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 10637126 (40.58 MB)
# Trainable params: 10637126 (40.58 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
# Fold 5/10
# Epoch 1/10
# 1/1 [==============================] - 1s 1s/step - loss: 1.7918 - accuracy: 0.1538 - val_loss: 1.7793 - val_accuracy: 0.1667
# Epoch 2/10
# 1/1 [==============================] - 0s 482ms/step - loss: 1.7834 - accuracy: 0.2692 - val_loss: 1.7115 - val_accuracy: 0.3333
# Epoch 3/10
# 1/1 [==============================] - 0s 461ms/step - loss: 1.7511 - accuracy: 0.2692 - val_loss: 1.6930 - val_accuracy: 0.3333
# Epoch 4/10
# 1/1 [==============================] - 0s 478ms/step - loss: 1.7738 - accuracy: 0.2692 - val_loss: 1.7154 - val_accuracy: 0.3333
# Epoch 5/10
# 1/1 [==============================] - 0s 459ms/step - loss: 1.7410 - accuracy: 0.3462 - val_loss: 1.7401 - val_accuracy: 0.3333
# Epoch 6/10
# 1/1 [==============================] - 0s 458ms/step - loss: 1.7415 - accuracy: 0.3846 - val_loss: 1.7321 - val_accuracy: 0.3333
# Epoch 7/10
# 1/1 [==============================] - 0s 490ms/step - loss: 1.7354 - accuracy: 0.2692 - val_loss: 1.7109 - val_accuracy: 0.3333
# Epoch 8/10
# 1/1 [==============================] - 0s 455ms/step - loss: 1.7252 - accuracy: 0.2692 - val_loss: 1.6924 - val_accuracy: 0.3333
# Epoch 9/10
# 1/1 [==============================] - 0s 466ms/step - loss: 1.7074 - accuracy: 0.2692 - val_loss: 1.6808 - val_accuracy: 0.3333
# Epoch 10/10
# 1/1 [==============================] - 0s 453ms/step - loss: 1.6872 - accuracy: 0.2692 - val_loss: 1.6797 - val_accuracy: 0.3333
# 94/94 [==============================] - 6s 64ms/step - loss: 39.7618 - accuracy: 0.1457
# Test Accuracy for Fold 5: 0.1456666737794876
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 148, 148, 32)      896
#
#  max_pooling2d_10 (MaxPooli  (None, 74, 74, 32)        0
#  ng2D)
#
#  conv2d_11 (Conv2D)          (None, 72, 72, 64)        18496
#
#  max_pooling2d_11 (MaxPooli  (None, 36, 36, 64)        0
#  ng2D)
#
#  flatten_5 (Flatten)         (None, 82944)             0
#
#  dense_10 (Dense)            (None, 128)               10616960
#
#  dense_11 (Dense)            (None, 6)                 774
#
# =================================================================
# Total params: 10637126 (40.58 MB)
# Trainable params: 10637126 (40.58 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
# Fold 6/10
# Epoch 1/10
# 1/1 [==============================] - 1s 1s/step - loss: 1.7918 - accuracy: 0.0769 - val_loss: 1.7821 - val_accuracy: 0.3333
# Epoch 2/10
# 1/1 [==============================] - 0s 469ms/step - loss: 1.7833 - accuracy: 0.2692 - val_loss: 1.7380 - val_accuracy: 0.3333
# Epoch 3/10
# 1/1 [==============================] - 0s 457ms/step - loss: 1.7532 - accuracy: 0.2692 - val_loss: 1.7181 - val_accuracy: 0.3333
# Epoch 4/10
# 1/1 [==============================] - 0s 492ms/step - loss: 1.7670 - accuracy: 0.2692 - val_loss: 1.6905 - val_accuracy: 0.3333
# Epoch 5/10
# 1/1 [==============================] - 0s 467ms/step - loss: 1.7453 - accuracy: 0.2692 - val_loss: 1.6939 - val_accuracy: 0.3333
# Epoch 6/10
# 1/1 [==============================] - 0s 465ms/step - loss: 1.7421 - accuracy: 0.2692 - val_loss: 1.7022 - val_accuracy: 0.3333
# Epoch 7/10
# 1/1 [==============================] - 0s 481ms/step - loss: 1.7437 - accuracy: 0.2692 - val_loss: 1.6999 - val_accuracy: 0.3333
# Epoch 8/10
# 1/1 [==============================] - 0s 467ms/step - loss: 1.7409 - accuracy: 0.2692 - val_loss: 1.6880 - val_accuracy: 0.3333
# Epoch 9/10
# 1/1 [==============================] - 0s 462ms/step - loss: 1.7344 - accuracy: 0.2692 - val_loss: 1.6714 - val_accuracy: 0.3333
# Epoch 10/10
# 1/1 [==============================] - 0s 451ms/step - loss: 1.7293 - accuracy: 0.2692 - val_loss: 1.6539 - val_accuracy: 0.3333
# 94/94 [==============================] - 6s 64ms/step - loss: 14.4746 - accuracy: 0.1467
# Test Accuracy for Fold 6: 0.14666666090488434
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 148, 148, 32)      896
#
#  max_pooling2d_12 (MaxPooli  (None, 74, 74, 32)        0
#  ng2D)
#
#  conv2d_13 (Conv2D)          (None, 72, 72, 64)        18496
#
#  max_pooling2d_13 (MaxPooli  (None, 36, 36, 64)        0
#  ng2D)
#
#  flatten_6 (Flatten)         (None, 82944)             0
#
#  dense_12 (Dense)            (None, 128)               10616960
#
#  dense_13 (Dense)            (None, 6)                 774
#
# =================================================================
# Total params: 10637126 (40.58 MB)
# Trainable params: 10637126 (40.58 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
# Fold 7/10
# Epoch 1/10
# 1/1 [==============================] - 1s 1s/step - loss: 1.7917 - accuracy: 0.2308 - val_loss: 1.7817 - val_accuracy: 0.1667
# Epoch 2/10
# 1/1 [==============================] - 0s 478ms/step - loss: 1.7861 - accuracy: 0.1923 - val_loss: 1.7298 - val_accuracy: 0.3333
# Epoch 3/10
# 1/1 [==============================] - 0s 479ms/step - loss: 1.7598 - accuracy: 0.2692 - val_loss: 1.6691 - val_accuracy: 0.3333
# Epoch 4/10
# 1/1 [==============================] - 0s 477ms/step - loss: 1.7484 - accuracy: 0.2692 - val_loss: 1.6688 - val_accuracy: 0.3333
# Epoch 5/10
# 1/1 [==============================] - 0s 462ms/step - loss: 1.7456 - accuracy: 0.2692 - val_loss: 1.6925 - val_accuracy: 0.3333
# Epoch 6/10
# 1/1 [==============================] - 0s 483ms/step - loss: 1.7322 - accuracy: 0.2692 - val_loss: 1.7089 - val_accuracy: 0.3333
# Epoch 7/10
# 1/1 [==============================] - 0s 496ms/step - loss: 1.7256 - accuracy: 0.3462 - val_loss: 1.7059 - val_accuracy: 0.3333
# Epoch 8/10
# 1/1 [==============================] - 1s 500ms/step - loss: 1.7145 - accuracy: 0.2692 - val_loss: 1.6923 - val_accuracy: 0.3333
# Epoch 9/10
# 1/1 [==============================] - 1s 524ms/step - loss: 1.6949 - accuracy: 0.2692 - val_loss: 1.6845 - val_accuracy: 0.3333
# Epoch 10/10
# 1/1 [==============================] - 0s 464ms/step - loss: 1.6773 - accuracy: 0.3077 - val_loss: 1.6598 - val_accuracy: 0.3333
# 94/94 [==============================] - 6s 65ms/step - loss: 60.9347 - accuracy: 0.1457
# Test Accuracy for Fold 7: 0.1456666737794876
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_14 (Conv2D)          (None, 148, 148, 32)      896
#
#  max_pooling2d_14 (MaxPooli  (None, 74, 74, 32)        0
#  ng2D)
#
#  conv2d_15 (Conv2D)          (None, 72, 72, 64)        18496
#
#  max_pooling2d_15 (MaxPooli  (None, 36, 36, 64)        0
#  ng2D)
#
#  flatten_7 (Flatten)         (None, 82944)             0
#
#  dense_14 (Dense)            (None, 128)               10616960
#
#  dense_15 (Dense)            (None, 6)                 774
#
# =================================================================
# Total params: 10637126 (40.58 MB)
# Trainable params: 10637126 (40.58 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
# Fold 8/10
# Epoch 1/10
# 1/1 [==============================] - 1s 1s/step - loss: 1.7918 - accuracy: 0.1923 - val_loss: 1.7819 - val_accuracy: 0.3333
# Epoch 2/10
# 1/1 [==============================] - 0s 476ms/step - loss: 1.7841 - accuracy: 0.2692 - val_loss: 1.7326 - val_accuracy: 0.3333
# Epoch 3/10
# 1/1 [==============================] - 0s 480ms/step - loss: 1.7533 - accuracy: 0.2692 - val_loss: 1.6872 - val_accuracy: 0.3333
# Epoch 4/10
# 1/1 [==============================] - 0s 494ms/step - loss: 1.7550 - accuracy: 0.2692 - val_loss: 1.6856 - val_accuracy: 0.3333
# Epoch 5/10
# 1/1 [==============================] - 0s 476ms/step - loss: 1.7373 - accuracy: 0.2692 - val_loss: 1.6945 - val_accuracy: 0.3333
# Epoch 6/10
# 1/1 [==============================] - 0s 452ms/step - loss: 1.7275 - accuracy: 0.2692 - val_loss: 1.6988 - val_accuracy: 0.3333
# Epoch 7/10
# 1/1 [==============================] - 0s 471ms/step - loss: 1.7207 - accuracy: 0.2692 - val_loss: 1.6882 - val_accuracy: 0.3333
# Epoch 8/10
# 1/1 [==============================] - 0s 455ms/step - loss: 1.7084 - accuracy: 0.2692 - val_loss: 1.6691 - val_accuracy: 0.3333
# Epoch 9/10
# 1/1 [==============================] - 1s 507ms/step - loss: 1.6904 - accuracy: 0.2692 - val_loss: 1.6475 - val_accuracy: 0.3333
# Epoch 10/10
# 1/1 [==============================] - 1s 550ms/step - loss: 1.6707 - accuracy: 0.2692 - val_loss: 1.6208 - val_accuracy: 0.3333
# 94/94 [==============================] - 6s 65ms/step - loss: 32.5694 - accuracy: 0.1457
# Test Accuracy for Fold 8: 0.1456666737794876
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_16 (Conv2D)          (None, 148, 148, 32)      896
#
#  max_pooling2d_16 (MaxPooli  (None, 74, 74, 32)        0
#  ng2D)
#
#  conv2d_17 (Conv2D)          (None, 72, 72, 64)        18496
#
#  max_pooling2d_17 (MaxPooli  (None, 36, 36, 64)        0
#  ng2D)
#
#  flatten_8 (Flatten)         (None, 82944)             0
#
#  dense_16 (Dense)            (None, 128)               10616960
#
#  dense_17 (Dense)            (None, 6)                 774
#
# =================================================================
# Total params: 10637126 (40.58 MB)
# Trainable params: 10637126 (40.58 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
# Fold 9/10
# Epoch 1/10
# 1/1 [==============================] - 1s 1s/step - loss: 1.7917 - accuracy: 0.2308 - val_loss: 1.7786 - val_accuracy: 0.5000
# Epoch 2/10
# 1/1 [==============================] - 0s 498ms/step - loss: 1.7832 - accuracy: 0.3462 - val_loss: 1.7089 - val_accuracy: 0.3333
# Epoch 3/10
# 1/1 [==============================] - 1s 527ms/step - loss: 1.7465 - accuracy: 0.2692 - val_loss: 1.6924 - val_accuracy: 0.3333
# Epoch 4/10
# 1/1 [==============================] - 0s 481ms/step - loss: 1.7923 - accuracy: 0.2692 - val_loss: 1.6741 - val_accuracy: 0.3333
# Epoch 5/10
# 1/1 [==============================] - 1s 511ms/step - loss: 1.7371 - accuracy: 0.2692 - val_loss: 1.7071 - val_accuracy: 0.3333
# Epoch 6/10
# 1/1 [==============================] - 0s 499ms/step - loss: 1.7364 - accuracy: 0.2692 - val_loss: 1.7193 - val_accuracy: 0.3333
# Epoch 7/10
# 1/1 [==============================] - 0s 449ms/step - loss: 1.7368 - accuracy: 0.2692 - val_loss: 1.7078 - val_accuracy: 0.3333
# Epoch 8/10
# 1/1 [==============================] - 0s 491ms/step - loss: 1.7242 - accuracy: 0.2692 - val_loss: 1.6783 - val_accuracy: 0.3333
# Epoch 9/10
# 1/1 [==============================] - 0s 459ms/step - loss: 1.7043 - accuracy: 0.2692 - val_loss: 1.6294 - val_accuracy: 0.3333
# Epoch 10/10
# 1/1 [==============================] - 0s 467ms/step - loss: 1.6810 - accuracy: 0.2692 - val_loss: 1.5910 - val_accuracy: 0.3333
# 94/94 [==============================] - 6s 65ms/step - loss: 39.6847 - accuracy: 0.1457
# Test Accuracy for Fold 9: 0.1456666737794876
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_18 (Conv2D)          (None, 148, 148, 32)      896
#
#  max_pooling2d_18 (MaxPooli  (None, 74, 74, 32)        0
#  ng2D)
#
#  conv2d_19 (Conv2D)          (None, 72, 72, 64)        18496
#
#  max_pooling2d_19 (MaxPooli  (None, 36, 36, 64)        0
#  ng2D)
#
#  flatten_9 (Flatten)         (None, 82944)             0
#
#  dense_18 (Dense)            (None, 128)               10616960
#
#  dense_19 (Dense)            (None, 6)                 774
#
# =================================================================
# Total params: 10637126 (40.58 MB)
# Trainable params: 10637126 (40.58 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
# Fold 10/10
# Epoch 1/10
# 1/1 [==============================] - 2s 2s/step - loss: 1.7917 - accuracy: 0.1923 - val_loss: 1.7726 - val_accuracy: 0.3333
# Epoch 2/10
# 1/1 [==============================] - 1s 545ms/step - loss: 1.7765 - accuracy: 0.2692 - val_loss: 1.7138 - val_accuracy: 0.3333
# Epoch 3/10
# 1/1 [==============================] - 1s 577ms/step - loss: 1.7542 - accuracy: 0.2692 - val_loss: 1.7024 - val_accuracy: 0.3333
# Epoch 4/10
# 1/1 [==============================] - 1s 542ms/step - loss: 1.7449 - accuracy: 0.2692 - val_loss: 1.7077 - val_accuracy: 0.3333
# Epoch 5/10
# 1/1 [==============================] - 0s 493ms/step - loss: 1.7412 - accuracy: 0.2692 - val_loss: 1.6929 - val_accuracy: 0.3333
# Epoch 6/10
# 1/1 [==============================] - 0s 497ms/step - loss: 1.7361 - accuracy: 0.2692 - val_loss: 1.6704 - val_accuracy: 0.3333
# Epoch 7/10
# 1/1 [==============================] - 0s 485ms/step - loss: 1.7308 - accuracy: 0.2692 - val_loss: 1.6629 - val_accuracy: 0.3333
# Epoch 8/10
# 1/1 [==============================] - 0s 485ms/step - loss: 1.7211 - accuracy: 0.2692 - val_loss: 1.6656 - val_accuracy: 0.3333
# Epoch 9/10
# 1/1 [==============================] - 0s 458ms/step - loss: 1.7106 - accuracy: 0.2692 - val_loss: 1.6443 - val_accuracy: 0.3333
# Epoch 10/10
# 1/1 [==============================] - 0s 464ms/step - loss: 1.6977 - accuracy: 0.2692 - val_loss: 1.6275 - val_accuracy: 0.3333
# 94/94 [==============================] - 6s 64ms/step - loss: 16.1053 - accuracy: 0.1533
# Test Accuracy for Fold 10: 0.15333333611488342
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_20 (Conv2D)          (None, 148, 148, 32)      896
#
#  max_pooling2d_20 (MaxPooli  (None, 74, 74, 32)        0
#  ng2D)
#
#  conv2d_21 (Conv2D)          (None, 72, 72, 64)        18496
#
#  max_pooling2d_21 (MaxPooli  (None, 36, 36, 64)        0
#  ng2D)
#
#  flatten_10 (Flatten)        (None, 82944)             0
#
#  dense_20 (Dense)            (None, 128)               10616960
#
#  dense_21 (Dense)            (None, 6)                 774
#
# =================================================================
# Total params: 10637126 (40.58 MB)
# Trainable params: 10637126 (40.58 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam

def simplified_alexnet(input_shape, num_classes):
    model = models.Sequential()

    model.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=input_shape))
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Conv2D(128, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Conv2D(256, (3, 3), activation='relu'))
    model.add(layers.Conv2D(256, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Flatten())
    model.add(layers.Dense(512, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(num_classes, activation='softmax'))

    optimizer = Adam(learning_rate=0.0001) 

    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

    return model


input_shape = (64, 64, 3)  
num_classes = 6  

model = simplified_alexnet(input_shape, num_classes)
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_31 (Conv2D)          (None, 62, 62, 64)        1792
#
#  max_pooling2d_27 (MaxPooli  (None, 31, 31, 64)        0
#  ng2D)
#
#  conv2d_32 (Conv2D)          (None, 29, 29, 128)       73856
#
#  max_pooling2d_28 (MaxPooli  (None, 14, 14, 128)       0
#  ng2D)
#
#  conv2d_33 (Conv2D)          (None, 12, 12, 256)       295168
#
#  conv2d_34 (Conv2D)          (None, 10, 10, 256)       590080
#
#  max_pooling2d_29 (MaxPooli  (None, 5, 5, 256)         0
#  ng2D)
#
#  flatten_12 (Flatten)        (None, 6400)              0
#
#  dense_24 (Dense)            (None, 512)               3277312
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_25 (Dense)            (None, 6)                 3078
#
# =================================================================
# Total params: 4241286 (16.18 MB)
# Trainable params: 4241286 (16.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Data generators
train_data = train_datagen.flow_from_directory(
    train_path,
    target_size=(64, 64),
    batch_size=32,
    class_mode='categorical'
)

val_data = val_test_datagen.flow_from_directory(
    test_path,
    target_size=(64, 64),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

test_data = val_test_datagen.flow_from_directory(
    test_path,
    target_size=(64, 64),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)


input_shape = (64, 64, 3)  
num_classes = 6 

model = simplified_alexnet(input_shape, num_classes)
model.summary()

# Train the model
history = model.fit(train_data, epochs=10, validation_data=val_data)

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(test_data)
print(f'Test Accuracy: {test_acc}')

# Display model summary
model.summary()
# Out:
# Found 14034 images belonging to 6 classes.
# Found 3000 images belonging to 6 classes.
# Found 3000 images belonging to 6 classes.
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_35 (Conv2D)          (None, 62, 62, 64)        1792
#
#  max_pooling2d_30 (MaxPooli  (None, 31, 31, 64)        0
#  ng2D)
#
#  conv2d_36 (Conv2D)          (None, 29, 29, 128)       73856
#
#  max_pooling2d_31 (MaxPooli  (None, 14, 14, 128)       0
#  ng2D)
#
#  conv2d_37 (Conv2D)          (None, 12, 12, 256)       295168
#
#  conv2d_38 (Conv2D)          (None, 10, 10, 256)       590080
#
#  max_pooling2d_32 (MaxPooli  (None, 5, 5, 256)         0
#  ng2D)
#
#  flatten_13 (Flatten)        (None, 6400)              0
#
#  dense_26 (Dense)            (None, 512)               3277312
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_27 (Dense)            (None, 6)                 3078
#
# =================================================================
# Total params: 4241286 (16.18 MB)
# Trainable params: 4241286 (16.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 439/439 [==============================] - 110s 249ms/step - loss: 1.1918 - accuracy: 0.5249 - val_loss: 0.9057 - val_accuracy: 0.6700
# Epoch 2/10
# 439/439 [==============================] - 101s 231ms/step - loss: 0.9263 - accuracy: 0.6469 - val_loss: 0.7960 - val_accuracy: 0.7137
# Epoch 3/10
# 439/439 [==============================] - 101s 231ms/step - loss: 0.8046 - accuracy: 0.7019 - val_loss: 0.7128 - val_accuracy: 0.7437
# Epoch 4/10
# 439/439 [==============================] - 101s 231ms/step - loss: 0.7361 - accuracy: 0.7317 - val_loss: 0.6863 - val_accuracy: 0.7593
# Epoch 5/10
# 439/439 [==============================] - 103s 235ms/step - loss: 0.6748 - accuracy: 0.7565 - val_loss: 0.5893 - val_accuracy: 0.7853
# Epoch 6/10
# 439/439 [==============================] - 102s 231ms/step - loss: 0.6344 - accuracy: 0.7715 - val_loss: 0.6391 - val_accuracy: 0.7707
# Epoch 7/10
# 439/439 [==============================] - 101s 231ms/step - loss: 0.6053 - accuracy: 0.7802 - val_loss: 0.5883 - val_accuracy: 0.7870
# Epoch 8/10
# 439/439 [==============================] - 101s 230ms/step - loss: 0.5659 - accuracy: 0.7956 - val_loss: 0.5855 - val_accuracy: 0.7883
# Epoch 9/10
# 439/439 [==============================] - 102s 233ms/step - loss: 0.5420 - accuracy: 0.8078 - val_loss: 0.5553 - val_accuracy: 0.8007
# Epoch 10/10
# 439/439 [==============================] - 103s 235ms/step - loss: 0.5196 - accuracy: 0.8142 - val_loss: 0.4975 - val_accuracy: 0.8243
# 94/94 [==============================] - 5s 49ms/step - loss: 0.4975 - accuracy: 0.8243
# Test Accuracy: 0.8243333101272583
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_35 (Conv2D)          (None, 62, 62, 64)        1792
#
#  max_pooling2d_30 (MaxPooli  (None, 31, 31, 64)        0
#  ng2D)
#
#  conv2d_36 (Conv2D)          (None, 29, 29, 128)       73856
#
#  max_pooling2d_31 (MaxPooli  (None, 14, 14, 128)       0
#  ng2D)
#
#  conv2d_37 (Conv2D)          (None, 12, 12, 256)       295168
#
#  conv2d_38 (Conv2D)          (None, 10, 10, 256)       590080
#
#  max_pooling2d_32 (MaxPooli  (None, 5, 5, 256)         0
#  ng2D)
#
#  flatten_13 (Flatten)        (None, 6400)              0
#
#  dense_26 (Dense)            (None, 512)               3277312
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_27 (Dense)            (None, 6)                 3078
#
# =================================================================
# Total params: 4241286 (16.18 MB)
# Trainable params: 4241286 (16.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
